# %% [markdown]
# # Python Scheduling Application

# %%
import os
from msilib import Binary

from pyomo.environ import *
from pyomo.opt import SolverFactory

import pandas as pd

# %%
os.environ["NEOS_EMAIL"] = "manyu1994@hotmail.com"

# %%
df = pd.read_excel("LP Sched Data.xlsx")

# %%
df
# Out:
#       Last Name First Name Credentials  Min Shifts  Max Shifts   Min Hours  \
# 0      Amonette    Melissa          MD          12          15  130.909091
# 1        Bahhur       Nael          MD          12          12  130.909091
# 2         Baker     Amanda          MD           0           5    0.000000
# 3         Baker     Eileen          MD          15          16  163.636364
# 4        Barnum     Monica         CNP           0           5    0.000000
# 5         Boggs     Thomas          MD           0           5    0.000000
# 6        Bretyl        Jen         CNP           0           5    0.000000
# 7         Bruss      Mitch          MD           0           5    0.000000
# 8      Chavalia    Shannon         CNP          13          13  141.818182
# 9         Erwin   Courtney          PA           0           5    0.000000
# 10      Goliver      Chris          MD          12          15  130.909091
# 11       Graber       Sara          MD           6           8   65.454545
# 12    Gruenbaum       Josh          MD          12          16  130.909091
# 13    Gruenbaum    Marissa          PA          12          14  130.909091
# 14      Harwani      Ashok          MD          15          18  163.636364
# 15      Helfman       Todd          DO          14          16  152.727273
# 16      Hussain        Zak          MD          12          12  130.909091
# 17    Meridieth        Tom         CNP          12          13  130.909091
# 18     Miksanek      Bryan          MD          13          16  141.818182
# 19       Morgan       Judy         CNP           0           5    0.000000
# 20       Murray       Adam          DO          15          16  163.636364
# 21       Murray  Alexandra          DO          14          14  152.727273
# 22       Nelson    Maureen          MD           0           5    0.000000
# 23     Neumeyer     Daniel          MD          15          15  163.636364
# 24        Payne     Nicole          DO           7           8   76.363636
# 25     Pontasch      Marty          MD           6           8   65.454545
# 26    Rashleigh      Megan         CNP           0           5    0.000000
# 27         Romp       Eric          PA          12          13  130.909091
# 28         Rupp     Morgan         CNP           0           5    0.000000
# 29        Scott        Tim          MD          15          15  163.636364
# 30       Secory     Brandy         CNP           6           8   65.454545
# 31       Taylor        Jay          MD          17          20  185.454545
# 32  Tull-Gratop      Clara         CNP           2           2   21.818182
# 33  Worthington       Rich          MD          14          17  152.727273
# 34        Young        Jim          MD          12          12  130.909091
# 35       Zeller      Kathy         CNP          12          14  130.909091
#
#      Max Hours  Min Consecutive AM Shifts  Min Consecutive PM Shifts  \
# 0   163.636364                          0                          2
# 1   130.909091                          0                          2
# 2    54.545455                          0                          0
# 3   174.545455                          1                          2
# 4    54.545455                          0                          0
# 5    54.545455                          0                          0
# 6    54.545455                          0                          0
# 7    54.545455                          0                          0
# 8   141.818182                          1                          0
# 9    54.545455                          0                          0
# 10  163.636364                          1                          0
# 11   87.272727                          1                          2
# 12  174.545455                          1                          2
# 13  152.727273                          1                          0
# 14  196.363636                          0                          2
# 15  174.545455                          1                          2
# 16  130.909091                          1                          0
# 17  141.818182                          1                          0
# 18  174.545455                          0                          2
# 19   54.545455                          0                          0
# 20  174.545455                          1                          2
# 21  152.727273                          0                          2
# 22   54.545455                          0                          0
# 23  163.636364                          0                          2
# 24   87.272727                          0                          2
# 25   87.272727                          1                          0
# 26   54.545455                          0                          0
# 27  141.818182                          1                          0
# 28   54.545455                          0                          0
# 29  163.636364                          1                          1
# 30   87.272727                          1                          0
# 31  218.181818                          1                          0
# 32   21.818182                          1                          0
# 33  185.454545                          1                          0
# 34  130.909091                          0                          2
# 35  152.727273                          1                          0
#
#     Max Consecutive AM Shifts  ...  Per Diem  Block Weekends (Fri, Sat, Sun)  \
# 0                           0  ...         0                               1
# 1                           0  ...         0                               1
# 2                           5  ...         1                               0
# 3                           4  ...         0                               1
# 4                           5  ...         1                               0
# 5                           5  ...         1                               0
# 6                           5  ...         1                               0
# 7                           5  ...         1                               0
# 8                           4  ...         0                               1
# 9                           5  ...         1                               0
# 10                          4  ...         0                               1
# 11                          4  ...         0                               0
# 12                          4  ...         0                               1
# 13                          4  ...         0                               1
# 14                          0  ...         0                               1
# 15                          4  ...         0                               1
# 16                          4  ...         0                               1
# 17                          4  ...         0                               1
# 18                          0  ...         0                               1
# 19                          5  ...         1                               0
# 20                          4  ...         0                               1
# 21                          0  ...         0                               1
# 22                          5  ...         1                               0
# 23                          0  ...         0                               1
# 24                          0  ...         0                               0
# 25                          3  ...         0                               0
# 26                          5  ...         1                               0
# 27                          4  ...         0                               1
# 28                          5  ...         1                               0
# 29                          4  ...         0                               1
# 30                          3  ...         0                               0
# 31                          6  ...         0                               1
# 32                          2  ...         0                               0
# 33                          4  ...         0                               1
# 34                          0  ...         0                               1
# 35                          4  ...         0                               1
#
#     AM Shift Percent  PM Shift Percent  Max PM shifts  \
# 0                0.0               1.0             15
# 1                0.0               1.0             12
# 2                0.0               1.0             10
# 3                0.8               0.2              3
# 4                1.0               0.0              0
# 5                0.5               0.5             10
# 6                1.0               0.0              0
# 7                0.5               0.5             10
# 8                1.0               0.0              0
# 9                1.0               0.0              0
# 10               1.0               0.0              3
# 11               0.5               0.5              3
# 12               0.8               0.2              4
# 13               1.0               0.0              0
# 14               0.0               1.0             18
# 15               0.8               0.2              3
# 16               1.0               0.0              0
# 17               1.0               0.0              0
# 18               0.0               1.0             16
# 19               1.0               0.0              0
# 20               0.2               0.8             16
# 21               0.0               1.0             14
# 22               0.5               0.5             10
# 23               0.0               1.0             15
# 24               0.0               1.0              8
# 25               1.0               0.0              0
# 26               1.0               0.0              0
# 27               1.0               0.0              0
# 28               1.0               0.0              0
# 29               0.8               0.2              3
# 30               1.0               0.0              0
# 31               1.0               0.0              0
# 32               1.0               0.0              0
# 33               0.8               0.2              3
# 34               0.0               1.0             12
# 35               1.0               0.0              0
#
#     Shifts off after PM before next AM  Defiance Percent  \
# 0                                    2          0.250000
# 1                                    2          0.000000
# 2                                    2          0.000000
# 3                                    2          0.333333
# 4                                    2          0.000000
# 5                                    2          0.000000
# 6                                    2          0.000000
# 7                                    2          0.250000
# 8                                    2          0.000000
# 9                                    2          0.000000
# 10                                   2          0.250000
# 11                                   2          0.250000
# 12                                   2          0.050000
# 13                                   2          0.000000
# 14                                   2          0.333333
# 15                                   2          0.250000
# 16                                   2          0.250000
# 17                                   2          0.000000
# 18                                   2          0.333333
# 19                                   2          0.000000
# 20                                   2          0.050000
# 21                                   2          0.250000
# 22                                   2          0.250000
# 23                                   2          0.250000
# 24                                   2          1.000000
# 25                                   2          0.250000
# 26                                   2          0.000000
# 27                                   2          0.000000
# 28                                   2          0.000000
# 29                                   2          0.250000
# 30                                   2          0.000000
# 31                                   2          0.050000
# 32                                   2          0.000000
# 33                                   2          1.000000
# 34                                   2          0.333333
# 35                                   2          0.000000
#
#     Fulton County Percent  Perrysburg Percent  Sylvania Percent
# 0                0.250000            0.250000          0.250000
# 1                1.000000            0.000000          0.000000
# 2                1.000000            0.000000          0.000000
# 3                0.000000            0.333333          0.333333
# 4                0.333333            0.333333          0.333333
# 5                1.000000            0.000000          0.000000
# 6                0.333333            0.333333          0.333333
# 7                0.250000            0.250000          0.250000
# 8                0.050000            0.050000          0.900000
# 9                0.333300            0.333333          0.333330
# 10               0.250000            0.250000          0.250000
# 11               0.250000            0.250000          0.250000
# 12               0.850000            0.050000          0.050000
# 13               0.050000            0.900000          0.050000
# 14               0.000000            0.333333          0.333333
# 15               0.250000            0.250000          0.250000
# 16               0.250000            0.250000          0.250000
# 17               0.050000            0.050000          0.900000
# 18               0.000000            0.333333          0.333333
# 19               0.333333            0.333333          0.333330
# 20               0.850000            0.050000          0.050000
# 21               0.250000            0.250000          0.250000
# 22               0.250000            0.250000          0.250000
# 23               0.250000            0.250000          0.250000
# 24               0.000000            0.000000          0.000000
# 25               0.250000            0.250000          0.250000
# 26               0.333333            0.333333          0.333333
# 27               0.500000            0.900000          0.050000
# 28               0.333333            0.333333          0.333333
# 29               0.000000            0.250000          0.500000
# 30               1.000000            0.000000          0.000000
# 31               0.850000            0.050000          0.050000
# 32               1.000000            0.000000          0.000000
# 33               0.000000            0.000000          0.000000
# 34               0.000000            0.333333          0.333333
# 35               0.900000            0.500000          0.050000
#
# [36 rows x 23 columns]

# %%
# Location
location = ['L' + str(i) for i in range(1, 4)]

# Shifts
shifts = ["Day", "Night", "Day & Night"]
# Define days (1 week)
week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
days = ['Day_' + str(i) + "_" + str(week[i%len(week)]) for i in range(1, 3)]
# Enter shifts of each day
monthly_shifts = {day: shifts for day in days}  # dict with day as key and list of its shifts as value

# Employee credentials
employee_credentials = ["CNP", "DO", "MD", "PA"]
# Enter workers ids (name, number, ...)
# workers = [ ('W' + str(i), employee_credentials[i%len(employee_credentials)] ) for i in range(1, 4)]  # 10 workers available

# %%
df["Full Name"] = df["Last Name"] + " " + df["First Name"]

workers = list(df["Full Name"])
workers
# Out:
# ['Amonette Melissa',
#  'Bahhur Nael',
#  'Baker Amanda',
#  'Baker Eileen',
#  'Barnum Monica',
#  'Boggs Thomas',
#  'Bretyl Jen',
#  'Bruss Mitch',
#  'Chavalia Shannon',
#  'Erwin Courtney',
#  'Goliver Chris',
#  'Graber Sara',
#  'Gruenbaum Josh',
#  'Gruenbaum Marissa',
#  'Harwani Ashok',
#  'Helfman Todd',
#  'Hussain Zak',
#  'Meridieth Tom',
#  'Miksanek Bryan',
#  'Morgan Judy',
#  'Murray Adam',
#  'Murray Alexandra',
#  'Nelson Maureen',
#  'Neumeyer Daniel',
#  'Payne Nicole',
#  'Pontasch Marty',
#  'Rashleigh Megan',
#  'Romp Eric',
#  'Rupp Morgan',
#  'Scott Tim',
#  'Secory Brandy',
#  'Taylor Jay',
#  'Tull-Gratop Clara',
#  'Worthington Rich',
#  'Young Jim',
#  'Zeller Kathy']

# %%
monthly_shifts
# Out:
# {'Day_1_Tue': ['Day', 'Night', 'Day & Night'],
#  'Day_2_Wed': ['Day', 'Night', 'Day & Night']}

# %%
workers
# Out:
# ['Amonette Melissa',
#  'Bahhur Nael',
#  'Baker Amanda',
#  'Baker Eileen',
#  'Barnum Monica',
#  'Boggs Thomas',
#  'Bretyl Jen',
#  'Bruss Mitch',
#  'Chavalia Shannon',
#  'Erwin Courtney',
#  'Goliver Chris',
#  'Graber Sara',
#  'Gruenbaum Josh',
#  'Gruenbaum Marissa',
#  'Harwani Ashok',
#  'Helfman Todd',
#  'Hussain Zak',
#  'Meridieth Tom',
#  'Miksanek Bryan',
#  'Morgan Judy',
#  'Murray Adam',
#  'Murray Alexandra',
#  'Nelson Maureen',
#  'Neumeyer Daniel',
#  'Payne Nicole',
#  'Pontasch Marty',
#  'Rashleigh Megan',
#  'Romp Eric',
#  'Rupp Morgan',
#  'Scott Tim',
#  'Secory Brandy',
#  'Taylor Jay',
#  'Tull-Gratop Clara',
#  'Worthington Rich',
#  'Young Jim',
#  'Zeller Kathy']

# %%
# df["workers with creds"] = (df["Last Name"] + " " + df["First Name"], df["Credentials"])
# df.to_json(orient="records")
# workers_creds = list(df["workers with creds"])
# workers_creds

workers_creds = []
for record in df.to_dict(orient="records"):
    workers_creds.append((record["Full Name"], record["Credentials"]))

workers_creds
# Out:
# [('Amonette Melissa', 'MD'),
#  ('Bahhur Nael', 'MD'),
#  ('Baker Amanda', 'MD'),
#  ('Baker Eileen', 'MD'),
#  ('Barnum Monica', 'CNP'),
#  ('Boggs Thomas', 'MD'),
#  ('Bretyl Jen', 'CNP'),
#  ('Bruss Mitch', 'MD'),
#  ('Chavalia Shannon', 'CNP'),
#  ('Erwin Courtney', 'PA'),
#  ('Goliver Chris', 'MD'),
#  ('Graber Sara', 'MD'),
#  ('Gruenbaum Josh', 'MD'),
#  ('Gruenbaum Marissa', 'PA'),
#  ('Harwani Ashok', 'MD'),
#  ('Helfman Todd', 'DO'),
#  ('Hussain Zak', 'MD'),
#  ('Meridieth Tom', 'CNP'),
#  ('Miksanek Bryan', 'MD'),
#  ('Morgan Judy', 'CNP'),
#  ('Murray Adam', 'DO'),
#  ('Murray Alexandra', 'DO'),
#  ('Nelson Maureen', 'MD'),
#  ('Neumeyer Daniel', 'MD'),
#  ('Payne Nicole', 'DO'),
#  ('Pontasch Marty', 'MD'),
#  ('Rashleigh Megan', 'CNP'),
#  ('Romp Eric', 'PA'),
#  ('Rupp Morgan', 'CNP'),
#  ('Scott Tim', 'MD'),
#  ('Secory Brandy', 'CNP'),
#  ('Taylor Jay', 'MD'),
#  ('Tull-Gratop Clara', 'CNP'),
#  ('Worthington Rich', 'MD'),
#  ('Young Jim', 'MD'),
#  ('Zeller Kathy', 'CNP')]

# %%
# Initialize model
model = ConcreteModel()

# binary variables representing if a worker is scheduled somewhere
model.works = Var(((worker, cred, day, shift) for worker, cred in workers_creds for day in days for shift in monthly_shifts[day]),
                  within=Binary, initialize=0)

# binary variables representing if a worker is necessary
model.needed = Var(workers, within=Binary, initialize=0)

# binary variables representing if a worker worked on sunday but not on saturday (avoid if possible)
model.no_pref = Var(workers, within=Binary, initialize=0)

# %%
# Define an objective function with model as input, to pass later
def obj_rule(m):
    c = len(workers)
    return sum(m.no_pref[worker] for worker in workers) + sum(c * m.needed[worker] for worker in workers)

# %%
# add objective function to the model. rule (pass function) or expr (pass expression directly)
model.obj = Objective(rule=obj_rule, sense=minimize)

# %%
model.works.__dict__
# Out:
# {'_rule_init': <pyomo.core.base.initializer.ConstantInitializer at 0x1fae1b9ef20>,
#  '_rule_domain': <pyomo.core.base.set.SetInitializer at 0x1fae1b9e500>,
#  '_dense': True,
#  '_units': None,
#  '_ctype': pyomo.core.base.var.Var,
#  'doc': None,
#  '_name': 'works',
#  '_constructed': True,
#  '_parent': <weakref at 0x000001FAE1B6D620; to 'ConcreteModel' at 0x000001FAE1B6D440>,
#  '_data': {('Amonette Melissa',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12845f0>,
#   ('Amonette Melissa',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284660>,
#   ('Amonette Melissa',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12846d0>,
#   ('Amonette Melissa',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284740>,
#   ('Amonette Melissa',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12847b0>,
#   ('Amonette Melissa',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284820>,
#   ('Bahhur Nael',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284890>,
#   ('Bahhur Nael',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284900>,
#   ('Bahhur Nael',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284970>,
#   ('Bahhur Nael',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12849e0>,
#   ('Bahhur Nael',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284a50>,
#   ('Bahhur Nael',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284ac0>,
#   ('Baker Amanda',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284b30>,
#   ('Baker Amanda',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284ba0>,
#   ('Baker Amanda',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284c10>,
#   ('Baker Amanda',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284c80>,
#   ('Baker Amanda',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284cf0>,
#   ('Baker Amanda',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284d60>,
#   ('Baker Eileen',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284dd0>,
#   ('Baker Eileen',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284e40>,
#   ('Baker Eileen',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284eb0>,
#   ('Baker Eileen',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284f20>,
#   ('Baker Eileen',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1284f90>,
#   ('Baker Eileen',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285000>,
#   ('Barnum Monica',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285070>,
#   ('Barnum Monica',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12850e0>,
#   ('Barnum Monica',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285150>,
#   ('Barnum Monica',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12851c0>,
#   ('Barnum Monica',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285230>,
#   ('Barnum Monica',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12852a0>,
#   ('Boggs Thomas',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285310>,
#   ('Boggs Thomas',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285380>,
#   ('Boggs Thomas',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12853f0>,
#   ('Boggs Thomas',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285460>,
#   ('Boggs Thomas',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12854d0>,
#   ('Boggs Thomas',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285540>,
#   ('Bretyl Jen',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12855b0>,
#   ('Bretyl Jen',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285620>,
#   ('Bretyl Jen',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285690>,
#   ('Bretyl Jen',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285700>,
#   ('Bretyl Jen',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285770>,
#   ('Bretyl Jen',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12857e0>,
#   ('Bruss Mitch',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285850>,
#   ('Bruss Mitch',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12858c0>,
#   ('Bruss Mitch',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285930>,
#   ('Bruss Mitch',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12859a0>,
#   ('Bruss Mitch',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285a10>,
#   ('Bruss Mitch',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285a80>,
#   ('Chavalia Shannon',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285af0>,
#   ('Chavalia Shannon',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285b60>,
#   ('Chavalia Shannon',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285bd0>,
#   ('Chavalia Shannon',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285c40>,
#   ('Chavalia Shannon',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285cb0>,
#   ('Chavalia Shannon',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285d20>,
#   ('Erwin Courtney',
#    'PA',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285d90>,
#   ('Erwin Courtney',
#    'PA',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285e00>,
#   ('Erwin Courtney',
#    'PA',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285e70>,
#   ('Erwin Courtney',
#    'PA',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285ee0>,
#   ('Erwin Courtney',
#    'PA',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285f50>,
#   ('Erwin Courtney',
#    'PA',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1285fc0>,
#   ('Goliver Chris',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286030>,
#   ('Goliver Chris',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12860a0>,
#   ('Goliver Chris',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286110>,
#   ('Goliver Chris',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286180>,
#   ('Goliver Chris',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12861f0>,
#   ('Goliver Chris',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286260>,
#   ('Graber Sara',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12862d0>,
#   ('Graber Sara',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286340>,
#   ('Graber Sara',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12863b0>,
#   ('Graber Sara',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286420>,
#   ('Graber Sara',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286490>,
#   ('Graber Sara',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286500>,
#   ('Gruenbaum Josh',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286570>,
#   ('Gruenbaum Josh',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12865e0>,
#   ('Gruenbaum Josh',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286650>,
#   ('Gruenbaum Josh',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12866c0>,
#   ('Gruenbaum Josh',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286730>,
#   ('Gruenbaum Josh',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12867a0>,
#   ('Gruenbaum Marissa',
#    'PA',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286810>,
#   ('Gruenbaum Marissa',
#    'PA',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286880>,
#   ('Gruenbaum Marissa',
#    'PA',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12868f0>,
#   ('Gruenbaum Marissa',
#    'PA',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286960>,
#   ('Gruenbaum Marissa',
#    'PA',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12869d0>,
#   ('Gruenbaum Marissa',
#    'PA',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286a40>,
#   ('Harwani Ashok',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286ab0>,
#   ('Harwani Ashok',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286b20>,
#   ('Harwani Ashok',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286b90>,
#   ('Harwani Ashok',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286c00>,
#   ('Harwani Ashok',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286c70>,
#   ('Harwani Ashok',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286ce0>,
#   ('Helfman Todd',
#    'DO',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286d50>,
#   ('Helfman Todd',
#    'DO',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286dc0>,
#   ('Helfman Todd',
#    'DO',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286e30>,
#   ('Helfman Todd',
#    'DO',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286ea0>,
#   ('Helfman Todd',
#    'DO',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286f10>,
#   ('Helfman Todd',
#    'DO',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286f80>,
#   ('Hussain Zak',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1286ff0>,
#   ('Hussain Zak',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287060>,
#   ('Hussain Zak',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12870d0>,
#   ('Hussain Zak',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287140>,
#   ('Hussain Zak',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12871b0>,
#   ('Hussain Zak',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287220>,
#   ('Meridieth Tom',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287290>,
#   ('Meridieth Tom',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287300>,
#   ('Meridieth Tom',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287370>,
#   ('Meridieth Tom',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12873e0>,
#   ('Meridieth Tom',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287450>,
#   ('Meridieth Tom',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12874c0>,
#   ('Miksanek Bryan',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287530>,
#   ('Miksanek Bryan',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12875a0>,
#   ('Miksanek Bryan',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287610>,
#   ('Miksanek Bryan',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287680>,
#   ('Miksanek Bryan',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12876f0>,
#   ('Miksanek Bryan',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287760>,
#   ('Morgan Judy',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae12877d0>,
#   ('Morgan Judy',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287840>,
#   ('Morgan Judy',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae12878b0>,
#   ('Morgan Judy',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287920>,
#   ('Morgan Judy',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287990>,
#   ('Morgan Judy',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287a00>,
#   ('Murray Adam',
#    'DO',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287a70>,
#   ('Murray Adam',
#    'DO',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287ae0>,
#   ('Murray Adam',
#    'DO',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287b50>,
#   ('Murray Adam',
#    'DO',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287bc0>,
#   ('Murray Adam',
#    'DO',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287c30>,
#   ('Murray Adam',
#    'DO',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287ca0>,
#   ('Murray Alexandra',
#    'DO',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287d10>,
#   ('Murray Alexandra',
#    'DO',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287d80>,
#   ('Murray Alexandra',
#    'DO',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287df0>,
#   ('Murray Alexandra',
#    'DO',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287e60>,
#   ('Murray Alexandra',
#    'DO',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287ed0>,
#   ('Murray Alexandra',
#    'DO',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae1287f40>,
#   ('Nelson Maureen',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c040>,
#   ('Nelson Maureen',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c0b0>,
#   ('Nelson Maureen',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c120>,
#   ('Nelson Maureen',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c190>,
#   ('Nelson Maureen',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c200>,
#   ('Nelson Maureen',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c270>,
#   ('Neumeyer Daniel',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c2e0>,
#   ('Neumeyer Daniel',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c350>,
#   ('Neumeyer Daniel',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c3c0>,
#   ('Neumeyer Daniel',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c430>,
#   ('Neumeyer Daniel',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c4a0>,
#   ('Neumeyer Daniel',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c510>,
#   ('Payne Nicole',
#    'DO',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c580>,
#   ('Payne Nicole',
#    'DO',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c5f0>,
#   ('Payne Nicole',
#    'DO',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c660>,
#   ('Payne Nicole',
#    'DO',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c6d0>,
#   ('Payne Nicole',
#    'DO',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c740>,
#   ('Payne Nicole',
#    'DO',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c7b0>,
#   ('Pontasch Marty',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c820>,
#   ('Pontasch Marty',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c890>,
#   ('Pontasch Marty',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c900>,
#   ('Pontasch Marty',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c970>,
#   ('Pontasch Marty',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123c9e0>,
#   ('Pontasch Marty',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123ca50>,
#   ('Rashleigh Megan',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cac0>,
#   ('Rashleigh Megan',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cb30>,
#   ('Rashleigh Megan',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cba0>,
#   ('Rashleigh Megan',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cc10>,
#   ('Rashleigh Megan',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cc80>,
#   ('Rashleigh Megan',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123ccf0>,
#   ('Romp Eric',
#    'PA',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cd60>,
#   ('Romp Eric',
#    'PA',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cdd0>,
#   ('Romp Eric',
#    'PA',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123ce40>,
#   ('Romp Eric',
#    'PA',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123ceb0>,
#   ('Romp Eric',
#    'PA',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cf20>,
#   ('Romp Eric',
#    'PA',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123cf90>,
#   ('Rupp Morgan',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d000>,
#   ('Rupp Morgan',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d070>,
#   ('Rupp Morgan',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d0e0>,
#   ('Rupp Morgan',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d150>,
#   ('Rupp Morgan',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d1c0>,
#   ('Rupp Morgan',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d230>,
#   ('Scott Tim',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d2a0>,
#   ('Scott Tim',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d310>,
#   ('Scott Tim',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d380>,
#   ('Scott Tim',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d3f0>,
#   ('Scott Tim',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d460>,
#   ('Scott Tim',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d4d0>,
#   ('Secory Brandy',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d540>,
#   ('Secory Brandy',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d5b0>,
#   ('Secory Brandy',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d620>,
#   ('Secory Brandy',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d690>,
#   ('Secory Brandy',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d700>,
#   ('Secory Brandy',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d770>,
#   ('Taylor Jay',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d7e0>,
#   ('Taylor Jay',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d850>,
#   ('Taylor Jay',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d8c0>,
#   ('Taylor Jay',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d930>,
#   ('Taylor Jay',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123d9a0>,
#   ('Taylor Jay',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123da10>,
#   ('Tull-Gratop Clara',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123da80>,
#   ('Tull-Gratop Clara',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123daf0>,
#   ('Tull-Gratop Clara',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123db60>,
#   ('Tull-Gratop Clara',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123dbd0>,
#   ('Tull-Gratop Clara',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123dc40>,
#   ('Tull-Gratop Clara',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123dcb0>,
#   ('Worthington Rich',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123dd20>,
#   ('Worthington Rich',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123dd90>,
#   ('Worthington Rich',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123de00>,
#   ('Worthington Rich',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123de70>,
#   ('Worthington Rich',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123dee0>,
#   ('Worthington Rich',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123df50>,
#   ('Young Jim',
#    'MD',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123dfc0>,
#   ('Young Jim',
#    'MD',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e030>,
#   ('Young Jim',
#    'MD',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e0a0>,
#   ('Young Jim',
#    'MD',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e110>,
#   ('Young Jim',
#    'MD',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e180>,
#   ('Young Jim',
#    'MD',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e1f0>,
#   ('Zeller Kathy',
#    'CNP',
#    'Day_1_Tue',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e260>,
#   ('Zeller Kathy',
#    'CNP',
#    'Day_1_Tue',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e2d0>,
#   ('Zeller Kathy',
#    'CNP',
#    'Day_1_Tue',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e340>,
#   ('Zeller Kathy',
#    'CNP',
#    'Day_2_Wed',
#    'Day'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e3b0>,
#   ('Zeller Kathy',
#    'CNP',
#    'Day_2_Wed',
#    'Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e420>,
#   ('Zeller Kathy',
#    'CNP',
#    'Day_2_Wed',
#    'Day & Night'): <pyomo.core.base.var._GeneralVarData at 0x1fae123e490>},
#  '_implicit_subsets': None,
#  '_index_set': <pyomo.core.base.set.OrderedScalarSet at 0x1fae1284580>,
#  '_rule_bounds': None}

# %% [markdown]
# # Constraints

# %%
model.constraints = ConstraintList()  # Create a set of constraints

# %%
for record in df.to_dict(orient="records"):
    print(record)
    print()
    model.constraints.add(
        40 >= sum(8 * model.works[worker, day, shift] for day in days for shift in days_shifts[day])
    )
# Out:
# {'Last Name': 'Amonette', 'First Name': 'Melissa', 'Credentials': 'MD', 'Min Shifts': 12, 'Max Shifts': 15, 'Min Hours': 130.9090909090909, 'Max Hours': 163.63636363636363, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 5, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 15, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Amonette Melissa'}
#
# {'Last Name': 'Bahhur', 'First Name': 'Nael', 'Credentials': 'MD', 'Min Shifts': 12, 'Max Shifts': 12, 'Min Hours': 130.9090909090909, 'Max Hours': 130.9090909090909, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 5, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 12, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 1.0, 'Perrysburg Percent': 0.0, 'Sylvania Percent': 0.0, 'Full Name': 'Bahhur Nael'}
#
# {'Last Name': 'Baker', 'First Name': 'Amanda', 'Credentials': 'MD', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 5, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 10, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 1.0, 'Perrysburg Percent': 0.0, 'Sylvania Percent': 0.0, 'Full Name': 'Baker Amanda'}
#
# {'Last Name': 'Baker', 'First Name': 'Eileen', 'Credentials': 'MD', 'Min Shifts': 15, 'Max Shifts': 16, 'Min Hours': 163.63636363636363, 'Max Hours': 174.54545454545453, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 3, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.8, 'PM Shift Percent': 0.19999999999999996, 'Max PM shifts': 3, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.3333333333333333, 'Fulton County Percent': 0.0, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Baker Eileen'}
#
# {'Last Name': 'Barnum', 'First Name': 'Monica', 'Credentials': 'CNP', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.3333333333333333, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Barnum Monica'}
#
# {'Last Name': 'Boggs', 'First Name': 'Thomas', 'Credentials': 'MD', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 5, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 0.5, 'PM Shift Percent': 0.5, 'Max PM shifts': 10, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 1.0, 'Perrysburg Percent': 0.0, 'Sylvania Percent': 0.0, 'Full Name': 'Boggs Thomas'}
#
# {'Last Name': 'Bretyl', 'First Name': 'Jen', 'Credentials': 'CNP', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.3333333333333333, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Bretyl Jen'}
#
# {'Last Name': 'Bruss', 'First Name': 'Mitch', 'Credentials': 'MD', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 5, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 0.5, 'PM Shift Percent': 0.5, 'Max PM shifts': 10, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Bruss Mitch'}
#
# {'Last Name': 'Chavalia', 'First Name': 'Shannon', 'Credentials': 'CNP', 'Min Shifts': 13, 'Max Shifts': 13, 'Min Hours': 141.8181818181818, 'Max Hours': 141.8181818181818, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.05, 'Perrysburg Percent': 0.05, 'Sylvania Percent': 0.9, 'Full Name': 'Chavalia Shannon'}
#
# {'Last Name': 'Erwin', 'First Name': 'Courtney', 'Credentials': 'PA', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.3333, 'Perrysburg Percent': 0.3333333, 'Sylvania Percent': 0.33333, 'Full Name': 'Erwin Courtney'}
#
# {'Last Name': 'Goliver', 'First Name': 'Chris', 'Credentials': 'MD', 'Min Shifts': 12, 'Max Shifts': 15, 'Min Hours': 130.9090909090909, 'Max Hours': 163.63636363636363, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 3, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Goliver Chris'}
#
# {'Last Name': 'Graber', 'First Name': 'Sara', 'Credentials': 'MD', 'Min Shifts': 6, 'Max Shifts': 8, 'Min Hours': 65.45454545454545, 'Max Hours': 87.27272727272727, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 2, 'Full Time': 0, 'Part Time': 1, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 0.5, 'PM Shift Percent': 0.5, 'Max PM shifts': 3, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Graber Sara'}
#
# {'Last Name': 'Gruenbaum', 'First Name': 'Josh', 'Credentials': 'MD', 'Min Shifts': 12, 'Max Shifts': 16, 'Min Hours': 130.9090909090909, 'Max Hours': 174.54545454545453, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 3, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.8, 'PM Shift Percent': 0.19999999999999996, 'Max PM shifts': 4, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.05, 'Fulton County Percent': 0.85, 'Perrysburg Percent': 0.05, 'Sylvania Percent': 0.05, 'Full Name': 'Gruenbaum Josh'}
#
# {'Last Name': 'Gruenbaum', 'First Name': 'Marissa', 'Credentials': 'PA', 'Min Shifts': 12, 'Max Shifts': 14, 'Min Hours': 130.9090909090909, 'Max Hours': 152.72727272727272, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.05, 'Perrysburg Percent': 0.9, 'Sylvania Percent': 0.05, 'Full Name': 'Gruenbaum Marissa'}
#
# {'Last Name': 'Harwani', 'First Name': 'Ashok', 'Credentials': 'MD', 'Min Shifts': 15, 'Max Shifts': 18, 'Min Hours': 163.63636363636363, 'Max Hours': 196.36363636363635, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 4, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 18, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.3333333333333333, 'Fulton County Percent': 0.0, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Harwani Ashok'}
#
# {'Last Name': 'Helfman', 'First Name': 'Todd', 'Credentials': 'DO', 'Min Shifts': 14, 'Max Shifts': 16, 'Min Hours': 152.72727272727272, 'Max Hours': 174.54545454545453, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 3, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.8, 'PM Shift Percent': 0.19999999999999996, 'Max PM shifts': 3, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Helfman Todd'}
#
# {'Last Name': 'Hussain', 'First Name': 'Zak', 'Credentials': 'MD', 'Min Shifts': 12, 'Max Shifts': 12, 'Min Hours': 130.9090909090909, 'Max Hours': 130.9090909090909, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Hussain Zak'}
#
# {'Last Name': 'Meridieth', 'First Name': 'Tom', 'Credentials': 'CNP', 'Min Shifts': 12, 'Max Shifts': 13, 'Min Hours': 130.9090909090909, 'Max Hours': 141.8181818181818, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.05, 'Perrysburg Percent': 0.05, 'Sylvania Percent': 0.9, 'Full Name': 'Meridieth Tom'}
#
# {'Last Name': 'Miksanek', 'First Name': 'Bryan', 'Credentials': 'MD', 'Min Shifts': 13, 'Max Shifts': 16, 'Min Hours': 141.8181818181818, 'Max Hours': 174.54545454545453, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 5, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 16, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.3333333333333333, 'Fulton County Percent': 0.0, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Miksanek Bryan'}
#
# {'Last Name': 'Morgan', 'First Name': 'Judy', 'Credentials': 'CNP', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.3333333333333333, 'Perrysburg Percent': 0.3333333, 'Sylvania Percent': 0.33333, 'Full Name': 'Morgan Judy'}
#
# {'Last Name': 'Murray', 'First Name': 'Adam', 'Credentials': 'DO', 'Min Shifts': 15, 'Max Shifts': 16, 'Min Hours': 163.63636363636363, 'Max Hours': 174.54545454545453, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 5, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.2, 'PM Shift Percent': 0.8, 'Max PM shifts': 16, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.05, 'Fulton County Percent': 0.85, 'Perrysburg Percent': 0.05, 'Sylvania Percent': 0.05, 'Full Name': 'Murray Adam'}
#
# {'Last Name': 'Murray', 'First Name': 'Alexandra', 'Credentials': 'DO', 'Min Shifts': 14, 'Max Shifts': 14, 'Min Hours': 152.72727272727272, 'Max Hours': 152.72727272727272, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 5, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 14, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Murray Alexandra'}
#
# {'Last Name': 'Nelson', 'First Name': 'Maureen', 'Credentials': 'MD', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 5, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 0.5, 'PM Shift Percent': 0.5, 'Max PM shifts': 10, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Nelson Maureen'}
#
# {'Last Name': 'Neumeyer', 'First Name': 'Daniel', 'Credentials': 'MD', 'Min Shifts': 15, 'Max Shifts': 15, 'Min Hours': 163.63636363636363, 'Max Hours': 163.63636363636363, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 5, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 15, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Neumeyer Daniel'}
#
# {'Last Name': 'Payne', 'First Name': 'Nicole', 'Credentials': 'DO', 'Min Shifts': 7, 'Max Shifts': 8, 'Min Hours': 76.36363636363636, 'Max Hours': 87.27272727272727, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 4, 'Full Time': 0, 'Part Time': 1, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 8, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 1.0, 'Fulton County Percent': 0.0, 'Perrysburg Percent': 0.0, 'Sylvania Percent': 0.0, 'Full Name': 'Payne Nicole'}
#
# {'Last Name': 'Pontasch', 'First Name': 'Marty', 'Credentials': 'MD', 'Min Shifts': 6, 'Max Shifts': 8, 'Min Hours': 65.45454545454545, 'Max Hours': 87.27272727272727, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 3, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 1, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.25, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.25, 'Full Name': 'Pontasch Marty'}
#
# {'Last Name': 'Rashleigh', 'First Name': 'Megan', 'Credentials': 'CNP', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.3333333333333333, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Rashleigh Megan'}
#
# {'Last Name': 'Romp', 'First Name': 'Eric', 'Credentials': 'PA', 'Min Shifts': 12, 'Max Shifts': 13, 'Min Hours': 130.9090909090909, 'Max Hours': 141.8181818181818, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.5, 'Perrysburg Percent': 0.9, 'Sylvania Percent': 0.05, 'Full Name': 'Romp Eric'}
#
# {'Last Name': 'Rupp', 'First Name': 'Morgan', 'Credentials': 'CNP', 'Min Shifts': 0, 'Max Shifts': 5, 'Min Hours': 0.0, 'Max Hours': 54.54545454545454, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 5, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 0, 'Per Diem': 1, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.3333333333333333, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Rupp Morgan'}
#
# {'Last Name': 'Scott', 'First Name': 'Tim', 'Credentials': 'MD', 'Min Shifts': 15, 'Max Shifts': 15, 'Min Hours': 163.63636363636363, 'Max Hours': 163.63636363636363, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 1, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 2, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.8, 'PM Shift Percent': 0.19999999999999996, 'Max PM shifts': 3, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.25, 'Fulton County Percent': 0.0, 'Perrysburg Percent': 0.25, 'Sylvania Percent': 0.5, 'Full Name': 'Scott Tim'}
#
# {'Last Name': 'Secory', 'First Name': 'Brandy', 'Credentials': 'CNP', 'Min Shifts': 6, 'Max Shifts': 8, 'Min Hours': 65.45454545454545, 'Max Hours': 87.27272727272727, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 3, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 1, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 1.0, 'Perrysburg Percent': 0.0, 'Sylvania Percent': 0.0, 'Full Name': 'Secory Brandy'}
#
# {'Last Name': 'Taylor', 'First Name': 'Jay', 'Credentials': 'MD', 'Min Shifts': 17, 'Max Shifts': 20, 'Min Hours': 185.45454545454544, 'Max Hours': 218.18181818181816, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 6, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.05, 'Fulton County Percent': 0.85, 'Perrysburg Percent': 0.05, 'Sylvania Percent': 0.05, 'Full Name': 'Taylor Jay'}
#
# {'Last Name': 'Tull-Gratop', 'First Name': 'Clara', 'Credentials': 'CNP', 'Min Shifts': 2, 'Max Shifts': 2, 'Min Hours': 21.818181818181817, 'Max Hours': 21.818181818181817, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 2, 'Max Consecutive PM Shifts': 0, 'Full Time': 0, 'Part Time': 1, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 0, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 1.0, 'Perrysburg Percent': 0.0, 'Sylvania Percent': 0.0, 'Full Name': 'Tull-Gratop Clara'}
#
# {'Last Name': 'Worthington', 'First Name': 'Rich', 'Credentials': 'MD', 'Min Shifts': 14, 'Max Shifts': 17, 'Min Hours': 152.72727272727272, 'Max Hours': 185.45454545454544, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 2, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.8, 'PM Shift Percent': 0.19999999999999996, 'Max PM shifts': 3, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 1.0, 'Fulton County Percent': 0.0, 'Perrysburg Percent': 0.0, 'Sylvania Percent': 0.0, 'Full Name': 'Worthington Rich'}
#
# {'Last Name': 'Young', 'First Name': 'Jim', 'Credentials': 'MD', 'Min Shifts': 12, 'Max Shifts': 12, 'Min Hours': 130.9090909090909, 'Max Hours': 130.9090909090909, 'Min Consecutive AM Shifts': 0, 'Min Consecutive PM Shifts': 2, 'Max Consecutive AM Shifts': 0, 'Max Consecutive PM Shifts': 3, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 0.0, 'PM Shift Percent': 1.0, 'Max PM shifts': 12, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.3333333333333333, 'Fulton County Percent': 0.0, 'Perrysburg Percent': 0.3333333333333333, 'Sylvania Percent': 0.3333333333333333, 'Full Name': 'Young Jim'}
#
# {'Last Name': 'Zeller', 'First Name': 'Kathy', 'Credentials': 'CNP', 'Min Shifts': 12, 'Max Shifts': 14, 'Min Hours': 130.9090909090909, 'Max Hours': 152.72727272727272, 'Min Consecutive AM Shifts': 1, 'Min Consecutive PM Shifts': 0, 'Max Consecutive AM Shifts': 4, 'Max Consecutive PM Shifts': 0, 'Full Time': 1, 'Part Time': 0, 'Per Diem': 0, 'Block Weekends (Fri, Sat, Sun)': 1, 'AM Shift Percent': 1.0, 'PM Shift Percent': 0.0, 'Max PM shifts': 0, 'Shifts off after PM before next AM': 2, 'Defiance Percent': 0.0, 'Fulton County Percent': 0.9, 'Perrysburg Percent': 0.5, 'Sylvania Percent': 0.05, 'Full Name': 'Zeller Kathy'}

# %%
# Constraint: no more than 40 hours worked
for worker in workers:
    model.constraints.add(
        40 >= sum(8 * model.works[worker, day, shift] for day in days for shift in days_shifts[day])
    )
